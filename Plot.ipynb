# %%
import os

# %%
import sys
import plotly.express as px

# %%
sys.path
# Out:
# ['/Users/haohsu/exp/covid_county_data',
#  '/Users/haohsu/exp/covid_county_data',
#  '/Users/haohsu/exp/covid_county_data/MOD_UTIL',
#  '/Users/haohsu/exp/covid_county_data/api',
#  '/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python38.zip',
#  '/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8',
#  '/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/lib-dynload',
#  '/usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8',
#  '',
#  '/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages',
#  '/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/haohsu/.ipython']

# %%
sys.path =['', '/usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python38.zip', '/usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8', '/usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/lib-dynload', '/usr/local/lib/python3.8/site-packages', '/usr/local/Cellar/protobuf/3.12.4/libexec/lib/python3.8/site-packages']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("res_fix2.csv", dtype={'fips': str})
df2 = pd.read_csv("res_fix.csv", dtype={'fips': str})

# %%
df1.head(10)
dates = df1["date"].unique()

# %%
ax = plt.subplots()

# %%
df1.plot(kind='line', x='fips', y='cases')
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='fips'>

# %%
piv_df = df1.pivot(index="date", columns="fips", values="cumulative_cases")
piv_df2 = df1.pivot(index="date", columns="fips", values="cumulative_deaths")
piv_df0 = df2.pivot(index="date", columns="fips", values="cumulative_cases")

# %%
print(len(piv_df), len(piv_df.columns))
# Out:
# 219 3202

# %%
cdf = df1[df1["fips"]=="01003"]
cdf.plot(x="date", y="cumulative_cases")
cdf["date"]
cdf.columns
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Index(['fips', 'population', 'date', 'cases', 'daily_deaths',
#        'cumulative_cases', 'cumulative_deaths'],
#       dtype='object')

# %%
print(len(piv_df.columns))
piv_df.iloc[:, : 100 ].plot()
# Out:
# 3202
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='date'>

# %%
piv_df0.iloc[:, :30 ].plot()
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='date'>

# %%
piv_df.plot()
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='date'>

# %%
# cols = piv_df.columns
cols = df1["fips"].unique()

# %%
i = 0
fig, ax = plt.subplots()
for x in cols:
#     sdf = df2[df2["fips"]==x]
    sdf = df1[df1["fips"]==x]
    if i % 100 == 0:
        print(x, len(sdf["date"]), i)
    sdf.plot(kind="line", x="date", y="cumulative_deaths", ax=ax, label=x)
#     ax.plot(df1[df1["fips"]==x]["date"], df1[df1["fips"]==x]["cumulative_deaths"])
#     df1[df1["fips"]==x].plot(x="date", y="cumulative_deaths", ax=ax, label="")
#     if i == 100:
#         break
    i += 1
# Out:
# 01001 219 0
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# 04013 219 100
# 06035 219 200
# 08119 219 300
# 13035 219 400
# 13239 219 500
# 17021 219 600
# 18017 219 700
# 19033 219 800
# 20035 219 900
# 21025 219 1000
# 21225 219 1100
# 24027 219 1200
# 26149 219 1300
# 28009 219 1400
# 29045 219 1500
# 30017 219 1600
# 31113 219 1700
# 35033 219 1800
# 37057 219 1900
# 38057 219 2000
# 39151 219 2100
# 41021 219 2200
# 45007 219 2300
# 46117 219 2400
# 47183 219 2500

# %%
i = 0
fig, ax = plt.subplots()
for x in cols:
    print(x)
    sdf = df2[dfd["fips"]==x]
    sdf.plot(x="date", y="cumulative_deaths", ax=ax, label=x)
#     ax.plot(df1[df1["fips"]==x]["date"], df1[df1["fips"]==x]["cumulative_deaths"])
#     df1[df1["fips"]==x].plot(x="date", y="cumulative_deaths", ax=ax, label="")
    if i == 20:
        break
    i += 1
